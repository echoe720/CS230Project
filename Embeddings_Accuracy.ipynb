# %%
#this mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# enter the foldername in the Shared Google Drive
FOLDERNAME = 'Shared drives/CS 230 Project'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# now that we've mounted your Drive, this ensures that

# python files from within it.
import sys
sys.path.append('/content/drive/{}'.format(FOLDERNAME))

# %cd /content/drive/$FOLDERNAME/
# Out:
# Mounted at /content/drive
# /content/drive/Shared drives/CS 230 Project

# %%
#DON'T INCLUDE THIS FILE IT DOESN'T DO ANYTHING
import pandas as pd
import numpy as np
import os
import dill
import pandas as pd
import glob, csv
import nltk
import nltk
nltk.download('punkt')t
from nltk.tokenize import sent_tokenize
import pickle
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from sentence_transformers import SentenceTransformer, models, InputExample, losses, SentencesDataset
from torch import nn
from torch.utils.data import DataLoader

# %%
#load test set

# %%
#load embeddings

# %%
#load encoding model

# %%
#for each test example
#   use encoding model to create embedding
#   find embedding from training_examples closest to this
#   if distance is within some threshold it is that author
#   update accuracy
